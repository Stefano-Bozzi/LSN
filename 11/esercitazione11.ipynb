# %% [markdown]
# ## Laboratorio di Simulazione Numerica
#
# # ESERCITAZIONE 11 #

# %% [markdown]
# ### esercizio 11.1

# %% [markdown]
# In questo esercizio è stata studiata la dipendenza della regressione lineare effettuata tramite rete neurale presente nel jupyter notebook "LSN_Exercises_11.ipynb" da diversi parametri, quali:
# * Numero di epoche per il training: Nepochs;
# * Numero di dati per il training: Ntrain;
# * Il rumore dei dati prodotti per la sessione di training: $\sigma$
#
# Seguono i grafici riassuntivi dei risultati ottenuti variando questi parametri.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect
# generate training inputs
np.random.seed(0)

Ntrain=100
sigma =0.5 # noise standard deviation, for the moment it is absent
Nepochs=30

fig, axs = plt.subplots(1,2,figsize=(20,10))
x_train = np.random.uniform(-1, 1, Ntrain)
x_valid = np.random.uniform(-1, 1, math.floor(Ntrain/10))
x_valid.sort()
y_target = m * x_valid + b
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)
# compose the NN model
model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# get a summary of our composed model
model.summary()

# fit the model using training dataset
# over Nepochs[l] epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=Nepochs,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)

# return weights and biases
model.get_weights()

# look into training history
# Plot training & validation loss values
axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].set_title('Model loss: sigma='+str(sigma)+' Ntrain='+str(Ntrain)+' Nepochs='+str(Nepochs))
axs[0].grid(True)
for ax in axs.flat:
  ax.set(xlabel='Epoch', ylabel='Loss')
for ax in axs.flat:
  ax.label_outer()
axs[0].legend(['Train', 'Test'], loc='best')

x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
axs[1].scatter(x_predicted, y_predicted,color='r', label=str(model.get_weights()))
axs[1].plot(x_valid, y_target)
axs[1].legend(loc="upper right")
axs[1].set_title('Model prediction: sigma='+str(j)+' Ntrain='+str(i)+' Nepochs='+str(l))
axs[1].grid(True)
keras.backend.clear_session()

########################################################################################### 100 0.8 30

Ntrain=100
sigma =0.8 # noise standard deviation, for the moment it is absent
Nepochs=30

fig, axs = plt.subplots(1,2,figsize=(20,10))
x_train = np.random.uniform(-1, 1, Ntrain)
x_valid = np.random.uniform(-1, 1, math.floor(Ntrain/10))
x_valid.sort()
y_target = m * x_valid + b
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)
# compose the NN model1
model1 = tf.keras.Sequential()
model1.add(Dense(1, input_shape=(1,)))

# compile the model1 choosing optimizer, loss and metrics objects
model1.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# get a summary of our composed model1
model1.summary()

# fit the model1 using training dataset
# over Nepochs[l] epochs of 32 batch size each
# report training progress against validation data
history = model1.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=Nepochs,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)

# return weights and biases
model1.get_weights()

# look into training history
# Plot training & validation loss values
axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].set_title('Model loss: sigma='+str(sigma)+' Ntrain='+str(Ntrain)+' Nepochs='+str(Nepochs))
axs[0].grid(True)
for ax in axs.flat:
  ax.set(xlabel='Epoch', ylabel='Loss')
for ax in axs.flat:
  ax.label_outer()
axs[0].legend(['Train', 'Test'], loc='best')

x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model1.predict(x_predicted)
axs[1].scatter(x_predicted, y_predicted,color='r', label=str(model1.get_weights()))
axs[1].plot(x_valid, y_target)
axs[1].legend(loc="upper right")
axs[1].set_title('Model1 prediction: sigma='+str(j)+' Ntrain='+str(i)+' Nepochs='+str(l))
axs[1].grid(True)
keras.backend.clear_session()

########################################################################################### 100 0.5 50

Ntrain=100
sigma =0.5 # noise standard deviation, for the moment it is absent
Nepochs=50

fig, axs = plt.subplots(1,2,figsize=(20,10))
x_train = np.random.uniform(-1, 1, Ntrain)
x_valid = np.random.uniform(-1, 1, math.floor(Ntrain/10))
x_valid.sort()
y_target = m * x_valid + b
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)
# compose the NN model
model2 = tf.keras.Sequential()
model2.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model2.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# get a summary of our composed model
model2.summary()

# fit the model using training dataset
# over Nepochs[l] epochs of 32 batch size each
# report training progress against validation data
history = model2.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=Nepochs,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)

# return weights and biases
model2.get_weights()

# look into training history
# Plot training & validation loss values
axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].set_title('Model loss: sigma='+str(sigma)+' Ntrain='+str(Ntrain)+' Nepochs='+str(Nepochs))
axs[0].grid(True)
for ax in axs.flat:
  ax.set(xlabel='Epoch', ylabel='Loss')
for ax in axs.flat:
  ax.label_outer()
axs[0].legend(['Train', 'Test'], loc='best')

x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
axs[1].scatter(x_predicted, y_predicted,color='r', label=str(model2.get_weights()))
axs[1].plot(x_valid, y_target)
axs[1].legend(loc="upper right")
axs[1].set_title('Model prediction: sigma='+str(j)+' Ntrain='+str(i)+' Nepochs='+str(l))
axs[1].grid(True)
keras.backend.clear_session()

########################################################################################### 500 0.8 50

Ntrain=500
sigma =0.8 # noise standard deviation, for the moment it is absent
Nepochs=50

fig, axs = plt.subplots(1,2,figsize=(20,10))
x_train = np.random.uniform(-1, 1, Ntrain)
x_valid = np.random.uniform(-1, 1, math.floor(Ntrain/10))
x_valid.sort()
y_target = m * x_valid + b
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)
# compose the NN modelf
model4 = tf.keras.Sequential()
model4.add(Dense(1, input_shape=(1,)))

# compile the model4 choosing optimizer, loss and metrics objects
model4.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# get a summary of our composed modelf
model4.summary()

# fit the model4 using training dataset
# over Nepochs[l] epochs of 32 batch size each
# report training progress against validation data
history = model4.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=Nepochs,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)

# return weights and biases
model4.get_weights()

# look into training history
# Plot training & validation loss values
axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].set_title('Model loss: sigma='+str(sigma)+' Ntrain='+str(Ntrain)+' Nepochs='+str(Nepochs))
axs[0].grid(True)
for ax in axs.flat:
  ax.set(xlabel='Epoch', ylabel='Loss')
for ax in axs.flat:
  ax.label_outer()
axs[0].legend(['Train', 'Test'], loc='best')

x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model4.predict(x_predicted)
axs[1].scatter(x_predicted, y_predicted,color='r', label=str(model4.get_weights()))
axs[1].plot(x_valid, y_target)
axs[1].legend(loc="upper right")
axs[1].set_title('Model prediction: sigma='+str(j)+' Ntrain='+str(i)+' Nepochs='+str(l))
axs[1].grid(True)
keras.backend.clear_session()

########################################################################################### 1000 0.8 50

Ntrain=1000
sigma =0.8 # noise standard deviation, for the moment it is absent
Nepochs=50

fig, axs = plt.subplots(1,2,figsize=(20,10))
x_train = np.random.uniform(-1, 1, Ntrain)
x_valid = np.random.uniform(-1, 1, math.floor(Ntrain/10))
x_valid.sort()
y_target = m * x_valid + b
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)
# compose the NN modelf
modelf = tf.keras.Sequential()
modelf.add(Dense(1, input_shape=(1,)))

# compile the modelf choosing optimizer, loss and metrics objects
modelf.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# get a summary of our composed modelf
modelf.summary()

# fit the modelf using training dataset
# over Nepochs[l] epochs of 32 batch size each
# report training progress against validation data
history = modelf.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=Nepochs,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)

# return weights and biases
modelf.get_weights()

# look into training history
# Plot training & validation loss values
axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].set_title('Model loss: sigma='+str(sigma)+' Ntrain='+str(Ntrain)+' Nepochs='+str(Nepochs))
axs[0].grid(True)
for ax in axs.flat:
  ax.set(xlabel='Epoch', ylabel='Loss')
for ax in axs.flat:
  ax.label_outer()
axs[0].legend(['Train', 'Test'], loc='best')

x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = modelf.predict(x_predicted)
axs[1].scatter(x_predicted, y_predicted,color='r', label=str(modelf.get_weights()))
axs[1].plot(x_valid, y_target)
axs[1].legend(loc="upper right")
axs[1].set_title('Model prediction: sigma='+str(j)+' Ntrain='+str(i)+' Nepochs='+str(l))
axs[1].grid(True)
keras.backend.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# ...

# %% [markdown]
# Nel primo caso risultavano troppo pochi i dati di train, come le generazioni, infatti il risultato è pessimo. Provando ad aumentare la sigma non si nota alcun miglioramento, anzi si nota un peggioramento forse causa dei troppi pochi dati. Per cercare una più chiara spiegazione è stato aumentato il numero di epoche tornando ad una sigma di 0,5 e dall'andamento della loss si può vedere che raggiunge un valore più basso e si stabilizza di più. Mantenendo alto il numero di epoche è stato aumentato il numero di dati di training fino a 500 e riportato la sigma a 0,8. in questo caso si può notare che la regressione è molto migliore, infatti alzando la sigma l'algoritmo usa dati di training più vari e quindi è vero che necessita di più dati o di più tempo ma il risultato può contare su un training vasto, più diversificato e quindi migliore. Alzando il numero di dati di training ulteriormente il risultato è ancora migliore.

# %% [markdown]
# ### esercizio 11.2

# %% [markdown]
# Scopo di questo esercizio era invece estendere la Neural Network (NN) in modo da riuscire a ottenere un fit del polinomio di terzo grado seguente:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# per $x \in [-1,1]$
#
# variando oltre i parametri ottimizzati nell'esercizio precedente anche:
#
# - il numero di layers
# - il numero di neuroni in ogni layer
# - la funzione di attivazione
# - l'ottimizzatore
# - la loss function
#
# Seguono i grafici che rappresentano i vari risultati ottenuti variando e cercando di ottimizzare la NN.
#
# La trattazione riguardo l'utilizzo della rete neurale al di fuori del dominio utilizzato per il training verrà effettuata in ultimo.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
def f(x):
    m1=4
    m2=-3
    m3=-2
    m4=+3
    return m1+m2*x+m3*x**2+m4*x**3
    
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = f(x_valid) # ideal (target) linear function

sigma = 0.5 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(f(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(f(x_valid), sigma)
#plot train data
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_train, y_train, color='r', label='train data')
plt.legend()
plt.grid(True)
plt.show()
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Il grafico precedente mostra i dati generati sia per il training sia per la validazione.
# Segue il primo tentativo di adattare la NN.

# %%
model = tf.keras.Sequential()
model.add(Dense(10,input_shape=(1,),activation='relu'))
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)
# return weights and biases
model.get_weights()
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)
x_predicted = np.random.uniform(-1, 1, 500)
y_predicted = model.predict(x_predicted)

plt.figure(figsize=(10, 7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
#plt.xlim(-1,1)
#plt.ylim(1.5,5)
plt.grid(True)
plt.show()

x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model.predict(x_predicted)
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')

x_valid = np.random.uniform(-1.5, 1.5, 100)
x_valid.sort()
y_target = f(x_valid)
plt.plot(x_valid, y_target)
plt.grid(True)

# %% [markdown]
# Come si può notare dal grafico il risultato è scadente. Sono stati utilizzati solo due layer da 10 e 1 neurone rispettivamente.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
def f(x):
    m1=4
    m2=-3
    m3=-2
    m4=+3
    return m1+m2*x+m3*x**2+m4*x**3
    
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = f(x_valid) # ideal (target) linear function

sigma = 0.5 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(f(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(f(x_valid), sigma)
#plot train data
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_train, y_train, color='r', label='train data')
plt.legend()
plt.grid(True)
plt.show()
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
model = tf.keras.Sequential()
model.add(Dense(10,input_shape=(1,),activation='relu'))
model.add(Dense(10,input_shape=(1,),activation='relu'))
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)
# return weights and biases
model.get_weights()
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)
x_predicted = np.random.uniform(-1, 1, 500)
y_predicted = model.predict(x_predicted)

plt.figure(figsize=(10, 7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
#plt.xlim(-1,1)
#plt.ylim(1.5,5)
plt.grid(True)
plt.show()

x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model.predict(x_predicted)
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')

x_valid = np.random.uniform(-1.5, 1.5, 100)
x_valid.sort()
y_target = f(x_valid)
plt.plot(x_valid, y_target)
plt.grid(True)

# %% [markdown]
# In questo caso il numero di dati e le epoche sono rimasti invariati ma è stato aggiunto un layer intermedio di 10 neuroni, il risultato seppur scadente mostra già miglioramenti rispetto al precedente.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
def f(x):
    m1=4
    m2=-3
    m3=-2
    m4=+3
    return m1+m2*x+m3*x**2+m4*x**3
    
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = f(x_valid) # ideal (target) linear function

sigma = 0.5 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(f(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(f(x_valid), sigma)
#plot train data
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_train, y_train, color='r', label='train data')
plt.legend()
plt.grid(True)
plt.show()
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
model = tf.keras.Sequential()
model.add(Dense(30,input_shape=(1,),activation='relu'))
model.add(Dense(20,input_shape=(1,),activation='relu'))
model.add(Dense(10,input_shape=(1,),activation='relu'))
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)
# return weights and biases
model.get_weights()
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=0)
x_predicted = np.random.uniform(-1, 1, 500)
y_predicted = model.predict(x_predicted)

plt.figure(figsize=(10, 7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
#plt.xlim(-1,1)
#plt.ylim(1.5,5)
plt.grid(True)
plt.show()

x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model.predict(x_predicted)
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')

x_valid = np.random.uniform(-1.5, 1.5, 100)
x_valid.sort()
y_target = f(x_valid)
plt.plot(x_valid, y_target)
plt.grid(True)

# %% [markdown]
# In questo caso è stato modificato lo schema della rete neurale che diventa: 30-20-10-1. Come si può notare i miglioramenti non sono così importanti come ci si aspetterebbe dall'aggiunta di un layer di neuroni così ampio, allora è stato scelto di modificare il numero di dati di training (da 500 a 5000)oltre che all'ottimizzatore (non più sdg ma adam) e alla funzione di attivazione (non più relu ma tanh)

# %%
import matplotlib.pyplot as plt
import numpy as np
import math 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
def f(x):
    m1=4
    m2=-3
    m3=-2
    m4=+3
    return m1+m2*x+m3*x**2+m4*x**3
    
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 5000)
x_valid = np.random.uniform(-1, 1, 500)
x_valid.sort()
y_target = f(x_valid) # ideal (target) linear function

sigma = 0.5 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(f(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(f(x_valid), sigma)
#plot train data
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_train, y_train, color='r', label='train data')
plt.legend()
plt.grid(True)
plt.show()
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
model = tf.keras.Sequential()
model.add(Dense(40,input_shape=(1,),activation='relu'))
model.add(Dense(20,input_shape=(1,),activation='tanh'))
model.add(Dense(15,input_shape=(1,),activation='tanh'))
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)
# return weights and biases
model.get_weights()
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)
x_predicted = np.random.uniform(-1, 1, 500)
y_predicted = model.predict(x_predicted)

plt.figure(figsize=(10, 7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
#plt.xlim(-1,1)
#plt.ylim(1.5,5)
plt.grid(True)
plt.show()

x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model.predict(x_predicted)
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')

x_valid = np.random.uniform(-1.5, 1.5, 100)
x_valid.sort()
y_target = f(x_valid)
plt.plot(x_valid, y_target)
plt.grid(True)
# Out:
# ...
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0022 - mse: 0.0022

# %% [markdown]
# In questo caso i  miglioramenti sono ben visibili, è stato scelto comunque di apporre delle modifiche per testare altre tipologie di ottimizzatori o funzioni di loss.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
def f(x):
    m1=4
    m2=-3
    m3=-2
    m4=+3
    return m1+m2*x+m3*x**2+m4*x**3
    
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 5000)
x_valid = np.random.uniform(-1, 1, 500)
x_valid.sort()
y_target = f(x_valid) # ideal (target) linear function

sigma = 0.5 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(f(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(f(x_valid), sigma)
#plot train data
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_train, y_train, color='r', label='train data')
plt.legend()
plt.grid(True)
plt.show()
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))
plt.plot(x_valid, y_target, label='target')
plt.xlim(-1,1)
plt.ylim(1.5,5)
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
model = tf.keras.Sequential()
model.add(Dense(40,input_shape=(1,),activation='relu'))
model.add(Dense(20,input_shape=(1,),activation='tanh'))
model.add(Dense(15,input_shape=(1,),activation='tanh'))
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='adam', loss='logcosh', metrics=['logcosh'])

history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid),verbose=0)
# return weights and biases
model.get_weights()
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)
x_predicted = np.random.uniform(-1, 1, 500)
y_predicted = model.predict(x_predicted)

plt.figure(figsize=(10, 7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

plt.figure(figsize=(10, 7))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.xlim(80,100)
plt.ylim(0.1,0.15)
plt.show()


plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
#plt.xlim(-1,1)
#plt.ylim(1.5,5)
plt.grid(True)
plt.show()

x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model.predict(x_predicted)
plt.figure(figsize=(10, 7))
plt.scatter(x_predicted, y_predicted,color='r')

x_valid = np.random.uniform(-1.5, 1.5, 100)
x_valid.sort()
y_target = f(x_valid)
plt.plot(x_valid, y_target)
plt.grid(True)
# Out:
# ...
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017 - logcosh: 0.0017

# %% [markdown]
# In questo ultimo caso è stata modificata anche la loss function da mse a logcosh. E' stato scelto questo perché simile al mean squared error, ma non è affetto così fortemente da predizioni occasionalmente molto scorrette. Si può notare che i dati ottenuti sono i migliori tra tutte le reti neurali, compresa la precedente, infatti questa simulazione ha
#
# loss-logcosh: 0.1101
#
# contro il
#
# loss-mse: 0.2438
#
# I risultati sono considerati abbastanza buoni da ritenere sufficientementi i parametri trovati.
#
# E' molto interessante inoltre notare come con questo esempio si metta in luce un problema molto comune nelle reti neurali, ovvero il fatto che per dati al di fuori dell'intervallo di quelli utilizzati per il training la rete neurale non sia in grado di predirre questi dati, e di effetuare nel modo corretto la regressione.

# %% [markdown]
# ### esericizo 11.3

# %% [markdown]
# In questo esercizio è stato adattato il codice precedente per riuscire ad effettuare un fit di una funzione non più $f: R → R$ ma $f:R*R→R$.
#
# La funzione in questione è: $$f(x,y)=sin(x^2+y^2)$$
#
# nell'intervallo : $x \in [-3/2,3/2]$ e $y \in [-3/2,3/2]$.

# %%
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

def f(x,y):
	return np.sin(x*x+y*y)

np.random.seed(0)
n_train = 5000
n_valid = int(n_train/10)

x_train = np.zeros((n_train, 2))
x_valid = np.zeros((n_valid, 2))
y_train = np.zeros(n_train)
y_valid = np.zeros(n_valid)

sigma = 0.2

for i in range(n_train):
    x_train[i,0] = np.random.uniform(-1.5,1.5)
    x_train[i,1] = np.random.uniform(-1.5,1.5)
    y_train[i] = np.random.normal(f(x_train[i,0],x_train[i,1]),sigma)

for i in range(n_valid):
    x_valid[i,0] = np.random.uniform(-1.5,1.5)
    x_valid[i,1] = np.random.uniform(-1.5,1.5)
    y_valid[i] = np.random.normal(f(x_valid[i,0],x_valid[i,1]),sigma)


x = np.arange(-1.5,1.5, 0.03)
y = np.arange(-1.5,1.5, 0.03)
X, Y = np.meshgrid(x,y)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-3/2, 3/2, 0.005)
X, Y = np.meshgrid(x, y)
zs = np.array([f(x,y) for x,y in zip(np.ravel(X), np.ravel(Y))])
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z, alpha=0.3)
ax.scatter(np.transpose(x_valid)[0], np.transpose(x_valid)[1], y_valid, color='red', marker='.', label='Validation Data')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.5, 0, 'Z')

# %% [markdown]
# Nel grafico precedente si possono osservare i punti di validation in rosso e la funzione da fittare in blu.

# %%
model = tf.keras.Sequential()
model.add(Dense(40, input_shape=(2,), activation='relu'))
model.add(Dense(20, activation='tanh'))
model.add(Dense(15,activation='tanh'))
model.add(Dense(1))

model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid), verbose=0)

# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# evaluate model with the exact curve
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

x_predicted = np.zeros((n_valid,2))
y_target = np.zeros(n_valid)

for i in range(n_valid):
    x_predicted[i,0] = np.random.uniform(-1.5,1.5)
    x_predicted[i,1] = np.random.uniform(-1.5,1.5)
    y_target[i] = f(x_predicted[i,0],x_predicted[i,1])

y_predicted = np.transpose(model.predict(x_predicted))
#y_predicted -= y_target

fig = plt.figure(figsize=(11,8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(np.transpose(x_predicted)[0], np.transpose(x_predicted)[1], y_predicted, color='red', marker='.', label='Validation Data')
ax.set_xlabel('x', fontsize=20)
ax.set_ylabel('y', fontsize=20)
ax.set_zlabel('z', fontsize=20)
ax.text2D(0.05, 0.95, "Prediction ", transform=ax.transAxes, fontsize=20)
ax.view_init(20, 30)
plt.show()
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0516 - mse: 0.0516
#
# Test loss: 0.05164223164319992
# Test accuracy: 0.05164223164319992
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0516 - mse: 0.0516
#
# Test loss: 0.05164223164319992
# Test accuracy: 0.05164223164319992

# %% [markdown]
# Nel primo caso è stato usato un set di dati per il training di 5000 dati, la NN composta con 40-20-15-1, con attivazione relu nel primo e poi tanh nei successivi e poi ottimizzatore sgd e mse come loss, i risultati, come si evince anche dal grafico delle loss non sono molto soddisfacenti.
#
# In memoria di come la loss function logcosh e l'ottimizzatore adam avessero risolto le oscillazioni sporadiche di predizioni sono state sostituite a quelli presenti.
#
# E' stato inoltre aumentato il numero di dati di training da 5000 a 15000

# %%
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

def f(x,y):
	return np.sin(x*x+y*y)

np.random.seed(0)
n_train = 15000
n_valid = int(n_train/10)

x_train = np.zeros((n_train, 2))
x_valid = np.zeros((n_valid, 2))
y_train = np.zeros(n_train)
y_valid = np.zeros(n_valid)

sigma = 0.2

for i in range(n_train):
    x_train[i,0] = np.random.uniform(-1.5,1.5)
    x_train[i,1] = np.random.uniform(-1.5,1.5)
    y_train[i] = np.random.normal(f(x_train[i,0],x_train[i,1]),sigma)

for i in range(n_valid):
    x_valid[i,0] = np.random.uniform(-1.5,1.5)
    x_valid[i,1] = np.random.uniform(-1.5,1.5)
    y_valid[i] = np.random.normal(f(x_valid[i,0],x_valid[i,1]),sigma)


x = np.arange(-1.5,1.5, 0.03)
y = np.arange(-1.5,1.5, 0.03)
X, Y = np.meshgrid(x,y)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(-3/2, 3/2, 0.005)
X, Y = np.meshgrid(x, y)
zs = np.array([f(x,y) for x,y in zip(np.ravel(X), np.ravel(Y))])
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z, alpha=0.3)
ax.scatter(np.transpose(x_valid)[0], np.transpose(x_valid)[1], y_valid, color='red', marker='.', label='Validation Data')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.5, 0, 'Z')

# %%
modelc = tf.keras.Sequential()
modelc.add(Dense(40, input_shape=(2,), activation='relu'))
modelc.add(Dense(30, activation='tanh'))
modelc.add(Dense(15,activation='tanh'))
modelc.add(Dense(1))

modelc.compile(optimizer='adam', loss='logcosh', metrics=['logcosh'])


history = modelc.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid), verbose=0)

# evaluate model
score = modelc.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# evaluate model with the exact curve
score = modelc.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

x_predicted = np.zeros((n_valid,2))
y_target = np.zeros(n_valid)

for i in range(n_valid):
    x_predicted[i,0] = np.random.uniform(-1.5,1.5)
    x_predicted[i,1] = np.random.uniform(-1.5,1.5)
    y_target[i] = f(x_predicted[i,0],x_predicted[i,1])

y_predicted = np.transpose(modelc.predict(x_predicted))
#y_predicted -= y_target

fig = plt.figure(figsize=(11,8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(np.transpose(x_predicted)[0], np.transpose(x_predicted)[1], y_predicted, color='red', marker='.', label='Validation Data')
ax.set_xlabel('x', fontsize=20)
ax.set_ylabel('y', fontsize=20)
ax.set_zlabel('z', fontsize=20)
ax.text2D(0.05, 0.95, "Prediction ", transform=ax.transAxes, fontsize=20)
ax.view_init(20, 30)
plt.show()
# Out:
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0200 - logcosh: 0.0200
#
# Test loss: 0.02003692276775837
# Test accuracy: 0.02003692276775837
# 47/47 [==============================] - 0s 1ms/step - loss: 0.0200 - logcosh: 0.0200
#
# Test loss: 0.02003692276775837
# Test accuracy: 0.02003692276775837

# %% [markdown]
# Si può notare come sia il grafico delle predizioni sia quello delle loss risulti migliore.
